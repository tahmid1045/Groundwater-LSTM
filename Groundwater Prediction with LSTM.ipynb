# %% [markdown]
# ## Read Data

# %%
import pandas as pd
import numpy as np
import os

# %%
dataset_root = "./Seasons"
os.listdir(dataset_root)
# Out:
# ['Summer.csv', 'Summer_2.csv', 'Winter.csv', 'winter_pred.csv']

# %%
summer_df = pd.read_csv(os.path.join(dataset_root, "Summer.csv"))
summer_df.head()
# Out:
#     Station       X        Y  2000  2001  2002  2003  2004  2005  2006  ...  \
# 0  25470023  409854  5919495     0    62    37    40    15    34    64  ...
# 1  25480025  422075  5923197     0    80    53    66    68    57    51  ...
# 2  25480026  412183  5923933     0    49    36    54    76    63    38  ...
# 3  25481088  421783  5925854    86    75    54    55    55    48    35  ...
# 4  25490020  423475  5918019    25    30    55    23    27    28    26  ...
#
#    2011  2012  2013  2014  2015  2016  2017  2018  2019  2020
# 0    70    96    43    63    59    25    24    72    22     7
# 1    21    20    11    93    84    16     9    85    72    64
# 2    34    63    72    40    41     8    10    64    90    48
# 3    35    35    45    83    75    90    26    87    64    63
# 4    66    57    76    60    41    50    23    67    41    17
#
# [5 rows x 24 columns]

# %%
winter_df = pd.read_csv(os.path.join(dataset_root, "Winter.csv"))
winter_df.head()
# Out:
#     Station       X           Y  2000  2001  2002  2003  2004  2005  2006  \
# 0  25470023  409854  5919495.00     0    41    64    29     2    82    50
# 1  25480025  422075  5923197.00    79    95    77    64    46    50    77
# 2  25480026  412183  5923933.00    60    30    71    47    37    19    67
# 3  25481088  421783  5925854.00     0    85    74    13    78    65    55
# 4  25490020  423475  5918019.55    27    28    50    28    21    15    93
#
#    ...  2016  2017  2018  2019      2020       2021       2022       2023  \
# 0  ...    13    38    53    87  79.68895  76.899734  79.902374  79.901855
# 1  ...    90    84    69    65  86.04448  85.913506  85.819040  85.757220
# 2  ...    57    24    59    52  80.27586  80.641300  80.807014  80.890015
# 3  ...    81    31    14    79  76.36980  76.244820  76.204470  76.193180
# 4  ...    35    66    35    52  72.73278  70.759600  69.111860  68.091095
#
#         2024       2025
# 0  77.901870  81.902435
# 1  85.716736  85.689650
# 2  81.691360  82.309420
# 3  76.190180  76.189380
# 4  67.498020  67.162834
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Preparing Data
#
# Picking an example data row first and then load the whole dataset later

# %%
example = summer_df.iloc[4]
example
# Out:
# Station    25490020
# X            423475
# Y           5918019
# 2000             25
# 2001             30
# 2002             55
# 2003             23
# 2004             27
# 2005             28
# 2006             26
# 2007             12
# 2008             35
# 2009              9
# 2010             31
# 2011             66
# 2012             57
# 2013             76
# 2014             60
# 2015             41
# 2016             50
# 2017             23
# 2018             67
# 2019             41
# 2020             17
# Name: 4, dtype: int64

# %%
# drop these columns, as we don't need them
example = example.drop(["Station", "X", "Y"])
example
# Out:
# 2000    25
# 2001    30
# 2002    55
# 2003    23
# 2004    27
# 2005    28
# 2006    26
# 2007    12
# 2008    35
# 2009     9
# 2010    31
# 2011    66
# 2012    57
# 2013    76
# 2014    60
# 2015    41
# 2016    50
# 2017    23
# 2018    67
# 2019    41
# 2020    17
# Name: 4, dtype: int64

# %%
# pick columns
winter_col = winter_df.columns[3:]

# summer has one extra
summer_col = summer_df.columns[3:]

# %%
summer_data = summer_df.loc[:, summer_col].values
winter_data = winter_df.loc[:, winter_col].values

# %%
summer_data
# Out:
# array([[ 0, 62, 37, ..., 72, 22,  7],
#        [ 0, 80, 53, ..., 85, 72, 64],
#        [ 0, 49, 36, ..., 64, 90, 48],
#        ...,
#        [54, 61, 87, ..., 50, 45, 33],
#        [35, 60, 66, ..., 62, 53, 33],
#        [48, 52, 93, ..., 94, 81, 83]], dtype=int64)

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Create sequences and labes
#
# Last element of each data row is the label(target prediction) and the rest is input

# %%
def create_seq_label(data):
    seq = np.zeros(shape=(data.shape[0], data.shape[1] - 1))
    labels = np.zeros(shape=(data.shape[0], 1))
    
    for i in range(data.shape[0]):
        seq[i] = data[i][:-1]
        labels[i] = data[i][-1]

        
    return seq, labels

# %%
winter_seq, winter_labels = create_seq_label(winter_data)
summer_seq, summer_labels = create_seq_label(summer_data)

# %% [markdown]
# ## Split data into train-test sets
#
# Split ratio 50:50

# %%
from sklearn.model_selection import train_test_split

x_train_winter, x_test_winter, y_train_winter, y_test_winter = train_test_split(winter_seq, winter_labels, test_size=0.6)
x_train_summer, x_test_summer, y_train_summer, y_test_summer = train_test_split(summer_seq, summer_labels, test_size=0.6)

# %% [markdown]
# ## LSTM

# %%
import torch
from torch import nn
import torch.nn.functional as F

# %%
if torch.cuda.is_available():
    device = torch.device(f"cuda:{torch.cuda.current_device()}")
    print(f"Setting Device to -> {torch.cuda.get_device_name(torch.cuda.current_device())}")
else:
    device = torch.device("cpu")
    print("No gpu found, using cpu")
# Out:
# No gpu found, using cpu

# %% [markdown]
# #### Definition

# %%
class GrundwasserLSTM(nn.Module):
    def __init__(self, in_dim=1, hidden_dim=100, out_dim=1):
        super(GrundwasserLSTM, self).__init__()
        
        self.hidden_dim=hidden_dim
        
        self.lstm = nn.LSTM(in_dim, hidden_dim)
        self.linear = nn.Linear(hidden_dim, out_dim)
        
        # basically a square matrix
        self.hidden_cell = (torch.zeros(1,1,self.hidden_dim).to(device),
                            torch.zeros(1,1,self.hidden_dim).to(device))
        
    def forward(self, x):
        lstm_out, self.hidden_cell = self.lstm(x.view(len(x), 1, -1), self.hidden_cell)
        y = self.linear(lstm_out.view(len(x), -1))
        return y[-1]

# %% [markdown]
# #### Train

# %%
from tqdm import tqdm

def train_lstm(model, x, y, epochs=200, learning_rate=0.001):
    loss_fn = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    
    
    for e in tqdm(range(epochs), desc="train_lstm"):
        for t in range(x.shape[0]):
            optimizer.zero_grad()
            
            model.hidden_cell = (torch.zeros(1, 1, model.hidden_dim).to(device),
                            torch.zeros(1, 1, model.hidden_dim).to(device))
        
            x_t = x[t]
            # to tensor
            x_t = torch.from_numpy(x[t]).float().to(device)
            
            y_t = y[t]
            y_t = torch.from_numpy(y[t]).float().to(device)
    
            out = model(x_t)
            loss = loss_fn(out, y_t)
    
            loss.backward()
            optimizer.step()
        
    
        if e % 50 == 0:
            print ("Epoch [{}/{}], Loss: {:.4f}".format(e + 1, epochs, loss.item()))

# %% [markdown]
# ##### Train for Winter

# %%
winter_lstm = GrundwasserLSTM()
winter_lstm = winter_lstm.to(device)
print(winter_lstm)
# Out:
# GrundwasserLSTM(
#   (lstm): LSTM(1, 100)
#   (linear): Linear(in_features=100, out_features=1, bias=True)
# )

# %%
# %time train_lstm(model=winter_lstm, x=x_train_winter, y=y_train_winter)
# Out:
# train_lstm:   0%|▎                                                                     | 1/200 [00:00<01:10,  2.81it/s]
# Epoch [1/200], Loss: 5713.6377
# train_lstm:  26%|█████████████████▌                                                   | 51/200 [00:18<01:01,  2.44it/s]
# Epoch [51/200], Loss: 2.3166
# train_lstm:  50%|██████████████████████████████████▎                                 | 101/200 [00:39<00:52,  1.89it/s]
# Epoch [101/200], Loss: 4.5294
# train_lstm:  76%|███████████████████████████████████████████████████▎                | 151/200 [01:00<00:21,  2.25it/s]
# Epoch [151/200], Loss: 0.0789
# train_lstm: 100%|████████████████████████████████████████████████████████████████████| 200/200 [01:26<00:00,  2.32it/s]
# Wall time: 1min 26s

# %% [markdown]
# #### Infer

# %%
def predict(x, model):
    results = list()
    with torch.no_grad():
        for t in range(x.shape[0]):
            x_t = torch.from_numpy(x[t]).float().to(device)
            # it's a tensor, convert to numpy again
            predicted = model(x_t)
            results.append(predicted.cpu().detach().numpy())
            
    return results

# %%
y_pred = predict(x_test_winter, winter_lstm)

# %% [markdown]
# #### Evaluate

# %%
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_pred=y_pred, y_true=y_test_winter)

# %%
r2
# Out:
# 0.8385371092190064

# %%
mse = mse(y_pred=y_pred, y_true=y_test_winter)

# %%
mse
# Out:
# 3.0061799689668582

# %%
mae = mae(y_pred=y_pred, y_true=y_test_winter)

# %%
mae
# Out:
# 1.2754639973042805

# %% [markdown]
# ##### Train for Summer

# %%
summer_lstm = GrundwasserLSTM()
summer_lstm = summer_lstm.to(device)
print(summer_lstm)
# Out:
# GrundwasserLSTM(
#   (lstm): LSTM(1, 100)
#   (linear): Linear(in_features=100, out_features=1, bias=True)
# )

# %%
# %time train_lstm(model=summer_lstm, x=x_train_summer, y=y_train_summer)
# Out:
# train_lstm:   0%|▎                                                                     | 1/200 [00:00<00:55,  3.56it/s]
# Epoch [1/200], Loss: 1877.3406
# train_lstm:  26%|█████████████████▌                                                   | 51/200 [00:15<00:48,  3.07it/s]
# Epoch [51/200], Loss: 238.5326
# train_lstm:  50%|██████████████████████████████████▎                                 | 101/200 [00:33<00:42,  2.32it/s]
# Epoch [101/200], Loss: 220.8226
# train_lstm:  76%|███████████████████████████████████████████████████▎                | 151/200 [00:53<00:17,  2.85it/s]
# Epoch [151/200], Loss: 37.9495
# train_lstm: 100%|████████████████████████████████████████████████████████████████████| 200/200 [01:11<00:00,  2.81it/s]
# Wall time: 1min 11s

# %%
y_pred_2 = predict(x_test_summer, summer_lstm)

# %% [markdown]
# ### Save the trained model

# %%
if not os.path.exists(os.path.join(os.getcwd(), "saved_models")):
    os.mkdir(os.path.join(os.getcwd(), "saved_models"))


torch.save(winter_lstm.state_dict(), "./saved_models/winter")
torch.save(summer_lstm.state_dict(), "./saved_models/summer")

# %% [markdown]
# #### Preparing prediction model for Winter Data

# %%
def predict_winter(x, model):
    predicted_w = []
    for year in range(6):
        pred = predict(x, model)
        np.append(x, pred)
        predicted_w.append(pred[0])
    return predicted_w

# %% [markdown]
# #### Preparing prediction model for Summer Data

# %%
def predict_summer(x, model):
    predicted_s = []
    for year in range(5):
        pred = predict(x, model)
        np.append(x, pred)
        predicted_s.append(pred[0])
    return predicted_s

# %% [markdown]
# ## Creating a dataframe for winter prediction

# %%
winter_count = winter_df.shape[0]

# %%
winter_count
# Out:
# 95

# %%
def winter_pred():
    wp = dict()
    for i in range (winter_count):
        row = winter_df.iloc[i]
        station_name = row["Station"]
        row = row.drop(['Station','X','Y'])
        row = np.array([row])
        predict = predict_winter(row, winter_lstm)
        
        wp[station_name] = predict
    return wp

# %%
wp = winter_pred()

# %%
df_w = pd.DataFrame(list(wp.items()))

# %%
df_w
# Out:
#              0                                                  1
# 0   25470023.0  [[80.28582], [80.26513], [80.237625], [80.2115...
# 1   25480025.0  [[83.593254], [83.59252], [83.581406], [83.571...
# 2   25480026.0  [[81.56782], [81.65222], [81.64732], [81.64104...
# 3   25481088.0  [[76.25018], [76.23112], [76.20968], [76.18886...
# 4   25490020.0  [[68.22003], [68.241585], [68.25457], [68.2672...
# ..         ...                                                ...
# 90  30491510.0  [[82.699585], [82.697945], [82.696144], [82.69...
# 91  30491512.0  [[81.20746], [81.20567], [81.20407], [81.20254...
# 92  30491513.0  [[81.72599], [81.72321], [81.72045], [81.71787...
# 93  30509090.0  [[80.73162], [82.491295], [82.565926], [82.584...
# 94  30509093.0  [[81.63715], [81.63527], [81.63416], [81.63308...
#
# [95 rows x 2 columns]

# %%
wp
# Out:
# {25470023.0: [array([80.28582], dtype=float32),
#   array([80.26513], dtype=float32),
#   array([80.237625], dtype=float32),
#   array([80.211555], dtype=float32),
#   array([80.18684], dtype=float32),
#   array([80.1634], dtype=float32)],
#  25480025.0: [array([83.593254], dtype=float32),
#   array([83.59252], dtype=float32),
#   array([83.581406], dtype=float32),
#   array([83.57122], dtype=float32),
#   array([83.56108], dtype=float32),
#   array([83.55109], dtype=float32)],
#  25480026.0: [array([81.56782], dtype=float32),
#   array([81.65222], dtype=float32),
#   array([81.64732], dtype=float32),
#   array([81.641045], dtype=float32),
#   array([81.63485], dtype=float32),
#   array([81.628815], dtype=float32)],
#  25481088.0: [array([76.25018], dtype=float32),
#   array([76.23112], dtype=float32),
#   array([76.20968], dtype=float32),
#   array([76.18886], dtype=float32),
#   array([76.1688], dtype=float32),
#   array([76.1495], dtype=float32)],
#  25490020.0: [array([68.22003], dtype=float32),
#   array([68.241585], dtype=float32),
#   array([68.25457], dtype=float32),
#   array([68.267204], dtype=float32),
#   array([68.27941], dtype=float32),
#   array([68.29118], dtype=float32)],
#  25500006.0: [array([68.22306], dtype=float32),
#   array([68.231834], dtype=float32),
#   array([68.2353], dtype=float32),
#   array([68.23858], dtype=float32),
#   array([68.24175], dtype=float32),
#   array([68.244804], dtype=float32)],
#  25501075.0: [array([83.02079], dtype=float32),
#   array([83.093254], dtype=float32),
#   array([83.08148], dtype=float32),
#   array([83.078705], dtype=float32),
#   array([83.07514], dtype=float32),
#   array([83.071754], dtype=float32)],
#  25510027.0: [array([83.81198], dtype=float32),
#   array([83.79881], dtype=float32),
#   array([83.78069], dtype=float32),
#   array([83.76257], dtype=float32),
#   array([83.744896], dtype=float32),
#   array([83.727806], dtype=float32)],
#  26471092.0: [array([81.306854], dtype=float32),
#   array([81.28091], dtype=float32),
#   array([81.27143], dtype=float32),
#   array([81.26327], dtype=float32),
#   array([81.25536], dtype=float32),
#   array([81.24763], dtype=float32)],
#  26471094.0: [array([82.02269], dtype=float32),
#   array([82.47108], dtype=float32),
#   array([82.58994], dtype=float32),
#   array([82.60575], dtype=float32),
#   array([82.603386], dtype=float32),
#   array([82.59782], dtype=float32)],
#  26471095.0: [array([83.284904], dtype=float32),
#   array([83.31314], dtype=float32),
#   array([83.31524], dtype=float32),
#   array([83.31272], dtype=float32),
#   array([83.3092], dtype=float32),
#   array([83.30547], dtype=float32)],
#  26471097.0: [array([81.5451], dtype=float32),
#   array([81.55306], dtype=float32),
#   array([81.61354], dtype=float32),
#   array([81.69947], dtype=float32),
#   array([81.73564], dtype=float32),
#   array([81.743996], dtype=float32)],
#  26480022.0: [array([81.28127], dtype=float32),
#   array([81.31074], dtype=float32),
#   array([81.310394], dtype=float32),
#   array([81.306114], dtype=float32),
#   array([81.30127], dtype=float32),
#   array([81.29644], dtype=float32)],
#  26481051.0: [array([80.743385], dtype=float32),
#   array([80.70977], dtype=float32),
#   array([80.701454], dtype=float32),
#   array([80.69432], dtype=float32),
#   array([80.68736], dtype=float32),
#   array([80.68057], dtype=float32)],
#  26481052.0: [array([77.813065], dtype=float32),
#   array([78.492744], dtype=float32),
#   array([78.590614], dtype=float32),
#   array([78.58729], dtype=float32),
#   array([78.57851], dtype=float32),
#   array([78.57107], dtype=float32)],
#  26481057.0: [array([82.16544], dtype=float32),
#   array([82.18356], dtype=float32),
#   array([82.1837], dtype=float32),
#   array([82.182106], dtype=float32),
#   array([82.18037], dtype=float32),
#   array([82.17864], dtype=float32)],
#  26486009.0: [array([81.096725], dtype=float32),
#   array([81.12141], dtype=float32),
#   array([81.12495], dtype=float32),
#   array([81.12484], dtype=float32),
#   array([81.12386], dtype=float32),
#   array([81.12268], dtype=float32)],
#  26486011.0: [array([77.98702], dtype=float32),
#   array([79.625374], dtype=float32),
#   array([79.67392], dtype=float32),
#   array([79.66981], dtype=float32),
#   array([79.6646], dtype=float32),
#   array([79.65952], dtype=float32)],
#  26486016.0: [array([75.695595], dtype=float32),
#   array([75.6921], dtype=float32),
#   array([75.69575], dtype=float32),
#   array([75.69937], dtype=float32),
#   array([75.702934], dtype=float32),
#   array([75.70644], dtype=float32)],
#  26490030.0: [array([83.68038], dtype=float32),
#   array([83.68396], dtype=float32),
#   array([83.68363], dtype=float32),
#   array([83.68281], dtype=float32),
#   array([83.68171], dtype=float32),
#   array([83.68046], dtype=float32)],
#  26491061.0: [array([82.13532], dtype=float32),
#   array([82.08193], dtype=float32),
#   array([82.06722], dtype=float32),
#   array([82.05949], dtype=float32),
#   array([82.052666], dtype=float32),
#   array([82.04617], dtype=float32)],
#  26491067.0: [array([79.3196], dtype=float32),
#   array([79.39999], dtype=float32),
#   array([79.40424], dtype=float32),
#   array([79.40313], dtype=float32),
#   array([79.40163], dtype=float32),
#   array([79.40009], dtype=float32)],
#  26500002.0: [array([83.05163], dtype=float32),
#   array([83.08115], dtype=float32),
#   array([83.086044], dtype=float32),
#   array([83.08668], dtype=float32),
#   array([83.08621], dtype=float32),
#   array([83.08543], dtype=float32)],
#  26521010.0: [array([83.82557], dtype=float32),
#   array([83.829506], dtype=float32),
#   array([83.83049], dtype=float32),
#   array([83.83149], dtype=float32),
#   array([83.832466], dtype=float32),
#   array([83.83343], dtype=float32)],
#  27460295.0: [array([35.92409], dtype=float32),
#   array([34.610306], dtype=float32),
#   array([33.11705], dtype=float32),
#   array([33.167797], dtype=float32),
#   array([33.0516], dtype=float32),
#   array([33.093616], dtype=float32)],
#  27461019.0: [array([77.95013], dtype=float32),
#   array([82.84919], dtype=float32),
#   array([82.81274], dtype=float32),
#   array([82.79047], dtype=float32),
#   array([82.768364], dtype=float32),
#   array([82.74642], dtype=float32)],
#  27471020.0: [array([78.445076], dtype=float32),
#   array([79.78847], dtype=float32),
#   array([79.75936], dtype=float32),
#   array([79.71481], dtype=float32),
#   array([79.67061], dtype=float32),
#   array([79.62724], dtype=float32)],
#  27481012.0: [array([79.06446], dtype=float32),
#   array([79.03406], dtype=float32),
#   array([79.03179], dtype=float32),
#   array([79.0098], dtype=float32),
#   array([78.986435], dtype=float32),
#   array([78.9633], dtype=float32)],
#  27501027.0: [array([72.715775], dtype=float32),
#   array([74.93296], dtype=float32),
#   array([75.28864], dtype=float32),
#   array([75.296196], dtype=float32),
#   array([75.2786], dtype=float32),
#   array([75.259605], dtype=float32)],
#  27501047.0: [array([83.51593], dtype=float32),
#   array([83.45951], dtype=float32),
#   array([83.43499], dtype=float32),
#   array([83.41686], dtype=float32),
#   array([83.40049], dtype=float32),
#   array([83.38479], dtype=float32)],
#  27505015.0: [array([84.77667], dtype=float32),
#   array([84.75634], dtype=float32),
#   array([84.73257], dtype=float32),
#   array([84.711365], dtype=float32),
#   array([84.690834], dtype=float32),
#   array([84.670586], dtype=float32)],
#  27511003.0: [array([84.047035], dtype=float32),
#   array([84.03591], dtype=float32),
#   array([84.02424], dtype=float32),
#   array([84.01266], dtype=float32),
#   array([84.00121], dtype=float32),
#   array([83.98991], dtype=float32)],
#  27511009.0: [array([81.95525], dtype=float32),
#   array([81.946754], dtype=float32),
#   array([81.93832], dtype=float32),
#   array([81.92993], dtype=float32),
#   array([81.92161], dtype=float32),
#   array([81.913345], dtype=float32)],
#  27511010.0: [array([81.86399], dtype=float32),
#   array([81.85406], dtype=float32),
#   array([81.844246], dtype=float32),
#   array([81.83457], dtype=float32),
#   array([81.825005], dtype=float32),
#   array([81.81556], dtype=float32)],
#  27511011.0: [array([83.580444], dtype=float32),
#   array([83.56792], dtype=float32),
#   array([83.60757], dtype=float32),
#   array([83.5996], dtype=float32),
#   array([83.58337], dtype=float32),
#   array([83.56672], dtype=float32)],
#  27511090.0: [array([83.57905], dtype=float32),
#   array([83.56353], dtype=float32),
#   array([83.546974], dtype=float32),
#   array([83.5306], dtype=float32),
#   array([83.51455], dtype=float32),
#   array([83.49888], dtype=float32)],
#  27519029.0: [array([82.02499], dtype=float32),
#   array([82.01899], dtype=float32),
#   array([82.01296], dtype=float32),
#   array([82.0071], dtype=float32),
#   array([82.00138], dtype=float32),
#   array([81.99577], dtype=float32)],
#  27521005.0: [array([70.409225], dtype=float32),
#   array([70.63272], dtype=float32),
#   array([70.71509], dtype=float32),
#   array([70.82939], dtype=float32),
#   array([70.85937], dtype=float32),
#   array([70.868805], dtype=float32)],
#  27521086.0: [array([76.363266], dtype=float32),
#   array([76.62725], dtype=float32),
#   array([76.65359], dtype=float32),
#   array([76.68485], dtype=float32),
#   array([76.71645], dtype=float32),
#   array([76.74704], dtype=float32)],
#  28470002.0: [array([79.05114], dtype=float32),
#   array([78.67797], dtype=float32),
#   array([78.562614], dtype=float32),
#   array([78.51047], dtype=float32),
#   array([78.48139], dtype=float32),
#   array([78.46169], dtype=float32)],
#  28480021.0: [array([79.56518], dtype=float32),
#   array([79.68777], dtype=float32),
#   array([79.709854], dtype=float32),
#   array([79.7028], dtype=float32),
#   array([79.689476], dtype=float32),
#   array([79.674904], dtype=float32)],
#  28481093.0: [array([82.66364], dtype=float32),
#   array([82.74993], dtype=float32),
#   array([82.76215], dtype=float32),
#   array([82.761284], dtype=float32),
#   array([82.756744], dtype=float32),
#   array([82.75093], dtype=float32)],
#  28491008.0: [array([81.0891], dtype=float32),
#   array([81.32305], dtype=float32),
#   array([81.31393], dtype=float32),
#   array([81.306206], dtype=float32),
#   array([81.298676], dtype=float32),
#   array([81.29134], dtype=float32)],
#  28491016.0: [array([83.52821], dtype=float32),
#   array([83.54276], dtype=float32),
#   array([83.54052], dtype=float32),
#   array([83.535225], dtype=float32),
#   array([83.52909], dtype=float32),
#   array([83.5227], dtype=float32)],
#  28500636.0: [array([81.48873], dtype=float32),
#   array([81.48582], dtype=float32),
#   array([81.48258], dtype=float32),
#   array([81.47923], dtype=float32),
#   array([81.47586], dtype=float32),
#   array([81.47247], dtype=float32)],
#  28500652.0: [array([81.52807], dtype=float32),
#   array([81.525], dtype=float32),
#   array([81.522285], dtype=float32),
#   array([81.518135], dtype=float32),
#   array([81.5113], dtype=float32),
#   array([81.50366], dtype=float32)],
#  28501105.0: [array([66.49143], dtype=float32),
#   array([68.061295], dtype=float32),
#   array([68.297066], dtype=float32),
#   array([68.31782], dtype=float32),
#   array([68.35529], dtype=float32),
#   array([68.74373], dtype=float32)],
#  28501107.0: [array([81.09261], dtype=float32),
#   array([80.81863], dtype=float32),
#   array([80.80041], dtype=float32),
#   array([80.794106], dtype=float32),
#   array([80.78962], dtype=float32),
#   array([80.78561], dtype=float32)],
#  28501108.0: [array([80.65487], dtype=float32),
#   array([80.71545], dtype=float32),
#   array([80.72032], dtype=float32),
#   array([80.72578], dtype=float32),
#   array([80.73121], dtype=float32),
#   array([80.73618], dtype=float32)],
#  28501111.0: [array([76.164055], dtype=float32),
#   array([76.45823], dtype=float32),
#   array([76.49526], dtype=float32),
#   array([76.53183], dtype=float32),
#   array([76.563225], dtype=float32),
#   array([76.58849], dtype=float32)],
#  28510981.0: [array([83.18845], dtype=float32),
#   array([83.19296], dtype=float32),
#   array([83.18992], dtype=float32),
#   array([83.18661], dtype=float32),
#   array([83.18322], dtype=float32),
#   array([83.17979], dtype=float32)],
#  28510982.0: [array([81.771675], dtype=float32),
#   array([81.76838], dtype=float32),
#   array([81.76505], dtype=float32),
#   array([81.7617], dtype=float32),
#   array([81.75834], dtype=float32),
#   array([81.75495], dtype=float32)],
#  28511201.0: [array([81.31126], dtype=float32),
#   array([81.3064], dtype=float32),
#   array([81.30172], dtype=float32),
#   array([81.29718], dtype=float32),
#   array([81.29275], dtype=float32),
#   array([81.2884], dtype=float32)],
#  28511202.0: [array([81.47953], dtype=float32),
#   array([81.47588], dtype=float32),
#   array([81.47231], dtype=float32),
#   array([81.46876], dtype=float32),
#   array([81.4652], dtype=float32),
#   array([81.46169], dtype=float32)],
#  28511203.0: [array([76.751625], dtype=float32),
#   array([77.24594], dtype=float32),
#   array([77.391594], dtype=float32),
#   array([77.398674], dtype=float32),
#   array([77.39817], dtype=float32),
#   array([77.41809], dtype=float32)],
#  28511204.0: [array([82.18653], dtype=float32),
#   array([82.194885], dtype=float32),
#   array([82.1916], dtype=float32),
#   array([82.18778], dtype=float32),
#   array([82.18393], dtype=float32),
#   array([82.18008], dtype=float32)],
#  28511207.0: [array([82.04568], dtype=float32),
#   array([82.02279], dtype=float32),
#   array([82.00831], dtype=float32),
#   array([82.00242], dtype=float32),
#   array([81.99933], dtype=float32),
#   array([81.99699], dtype=float32)],
#  28511210.0: [array([69.36775], dtype=float32),
#   array([69.76643], dtype=float32),
#   array([69.865265], dtype=float32),
#   array([69.87585], dtype=float32),
#   array([69.87618], dtype=float32),
#   array([69.875565], dtype=float32)],
#  28511229.0: [array([70.865685], dtype=float32),
#   array([70.84905], dtype=float32),
#   array([70.832924], dtype=float32),
#   array([70.82268], dtype=float32),
#   array([70.8149], dtype=float32),
#   array([70.808174], dtype=float32)],
#  28511230.0: [array([83.33242], dtype=float32),
#   array([83.3482], dtype=float32),
#   array([83.34682], dtype=float32),
#   array([83.34455], dtype=float32),
#   array([83.34217], dtype=float32),
#   array([83.33976], dtype=float32)],
#  28511231.0: [array([81.61939], dtype=float32),
#   array([81.64718], dtype=float32),
#   array([81.64562], dtype=float32),
#   array([81.643616], dtype=float32),
#   array([81.641655], dtype=float32),
#   array([81.63973], dtype=float32)],
#  28519035.0: [array([81.83345], dtype=float32),
#   array([81.83071], dtype=float32),
#   array([81.82752], dtype=float32),
#   array([81.82426], dtype=float32),
#   array([81.820946], dtype=float32),
#   array([81.817604], dtype=float32)],
#  29470010.0: [array([81.408745], dtype=float32),
#   array([81.40652], dtype=float32),
#   array([81.40443], dtype=float32),
#   array([81.40244], dtype=float32),
#   array([81.40053], dtype=float32),
#   array([81.398674], dtype=float32)],
#  29472968.0: [array([81.27209], dtype=float32),
#   array([81.26969], dtype=float32),
#   array([81.264984], dtype=float32),
#   array([81.25779], dtype=float32),
#   array([81.25201], dtype=float32),
#   array([81.24813], dtype=float32)],
#  29472981.0: [array([82.230736], dtype=float32),
#   array([82.75309], dtype=float32),
#   array([82.77003], dtype=float32),
#   array([82.79095], dtype=float32),
#   array([82.81198], dtype=float32),
#   array([82.83289], dtype=float32)],
#  29481334.0: [array([80.24642], dtype=float32),
#   array([80.33633], dtype=float32),
#   array([80.35154], dtype=float32),
#   array([80.356155], dtype=float32),
#   array([80.35898], dtype=float32),
#   array([80.3615], dtype=float32)],
#  29483281.0: [array([82.630516], dtype=float32),
#   array([82.625755], dtype=float32),
#   array([82.625626], dtype=float32),
#   array([82.62415], dtype=float32),
#   array([82.622536], dtype=float32),
#   array([82.62093], dtype=float32)],
#  29484282.0: [array([81.434654], dtype=float32),
#   array([81.374596], dtype=float32),
#   array([81.35703], dtype=float32),
#   array([81.347786], dtype=float32),
#   array([81.340485], dtype=float32),
#   array([81.33373], dtype=float32)],
#  29490617.0: [array([68.15531], dtype=float32),
#   array([68.52018], dtype=float32),
#   array([68.54212], dtype=float32),
#   array([68.55091], dtype=float32),
#   array([68.558266], dtype=float32),
#   array([68.56539], dtype=float32)],
#  29490626.0: [array([81.23736], dtype=float32),
#   array([81.235985], dtype=float32),
#   array([81.23269], dtype=float32),
#   array([81.229355], dtype=float32),
#   array([81.226036], dtype=float32),
#   array([81.22271], dtype=float32)],
#  29490630.0: [array([81.27043], dtype=float32),
#   array([81.26568], dtype=float32),
#   array([81.2609], dtype=float32),
#   array([81.25611], dtype=float32),
#   array([81.25133], dtype=float32),
#   array([81.24655], dtype=float32)],
#  29490632.0: [array([81.374794], dtype=float32),
#   array([81.371635], dtype=float32),
#   array([81.36862], dtype=float32),
#   array([81.36573], dtype=float32),
#   array([81.36293], dtype=float32),
#   array([81.3602], dtype=float32)],
#  29490634.0: [array([66.77689], dtype=float32),
#   array([66.36346], dtype=float32),
#   array([66.611084], dtype=float32),
#   array([66.63465], dtype=float32),
#   array([66.64594], dtype=float32),
#   array([66.65204], dtype=float32)],
#  29491338.0: [array([81.54047], dtype=float32),
#   array([81.56207], dtype=float32),
#   array([81.56637], dtype=float32),
#   array([81.567535], dtype=float32),
#   array([81.56844], dtype=float32),
#   array([81.5693], dtype=float32)],
#  29499501.0: [array([78.38447], dtype=float32),
#   array([78.32607], dtype=float32),
#   array([78.32978], dtype=float32),
#   array([78.334435], dtype=float32),
#   array([78.33901], dtype=float32),
#   array([78.34348], dtype=float32)],
#  29499502.0: [array([83.33919], dtype=float32),
#   array([83.34153], dtype=float32),
#   array([83.33843], dtype=float32),
#   array([83.33473], dtype=float32),
#   array([83.330795], dtype=float32),
#   array([83.326744], dtype=float32)],
#  29499503.0: [array([83.251305], dtype=float32),
#   array([83.19721], dtype=float32),
#   array([83.1629], dtype=float32),
#   array([83.15078], dtype=float32),
#   array([83.14622], dtype=float32),
#   array([83.143684], dtype=float32)],
#  29501404.0: [array([81.0521], dtype=float32),
#   array([81.038445], dtype=float32),
#   array([81.0342], dtype=float32),
#   array([81.031364], dtype=float32),
#   array([81.02875], dtype=float32),
#   array([81.02619], dtype=float32)],
#  29510149.0: [array([82.11323], dtype=float32),
#   array([82.120766], dtype=float32),
#   array([82.11998], dtype=float32),
#   array([82.11839], dtype=float32),
#   array([82.11668], dtype=float32),
#   array([82.11497], dtype=float32)],
#  29510657.0: [array([67.96371], dtype=float32),
#   array([69.513374], dtype=float32),
#   array([69.71139], dtype=float32),
#   array([69.72198], dtype=float32),
#   array([69.72789], dtype=float32),
#   array([69.73314], dtype=float32)],
#  29510999.0: [array([82.64059], dtype=float32),
#   array([82.64387], dtype=float32),
#   array([82.64217], dtype=float32),
#   array([82.64019], dtype=float32),
#   array([82.638145], dtype=float32),
#   array([82.636086], dtype=float32)],
#  29519002.0: [array([74.75173], dtype=float32),
#   array([75.07421], dtype=float32),
#   array([75.12792], dtype=float32),
#   array([75.181465], dtype=float32),
#   array([75.233734], dtype=float32),
#   array([75.2844], dtype=float32)],
#  29519017.0: [array([81.66688], dtype=float32),
#   array([81.662926], dtype=float32),
#   array([81.65705], dtype=float32),
#   array([81.65113], dtype=float32),
#   array([81.645226], dtype=float32),
#   array([81.639336], dtype=float32)],
#  29519021.0: [array([83.42479], dtype=float32),
#   array([83.419556], dtype=float32),
#   array([83.4151], dtype=float32),
#   array([83.41105], dtype=float32),
#   array([83.4072], dtype=float32),
#   array([83.403496], dtype=float32)],
#  29519023.0: [array([82.066505], dtype=float32),
#   array([82.07961], dtype=float32),
#   array([82.0675], dtype=float32),
#   array([82.05178], dtype=float32),
#   array([82.03629], dtype=float32),
#   array([82.02126], dtype=float32)],
#  29519026.0: [array([83.59361], dtype=float32),
#   array([83.59063], dtype=float32),
#   array([83.587074], dtype=float32),
#   array([83.58366], dtype=float32),
#   array([83.58036], dtype=float32),
#   array([83.57714], dtype=float32)],
#  29519042.0: [array([81.80996], dtype=float32),
#   array([81.760506], dtype=float32),
#   array([81.79506], dtype=float32),
#   array([81.80241], dtype=float32),
#   array([81.79952], dtype=float32),
#   array([81.79483], dtype=float32)],
#  30491504.0: [array([83.27302], dtype=float32),
#   array([83.26014], dtype=float32),
#   array([83.25681], dtype=float32),
#   array([83.2535], dtype=float32),
#   array([83.25016], dtype=float32),
#   array([83.24685], dtype=float32)],
#  30491505.0: [array([80.53662], dtype=float32),
#   array([80.5705], dtype=float32),
#   array([80.57296], dtype=float32),
#   array([80.57089], dtype=float32),
#   array([80.56814], dtype=float32),
#   array([80.56532], dtype=float32)],
#  30491509.0: [array([81.170044], dtype=float32),
#   array([81.17731], dtype=float32),
#   array([81.17742], dtype=float32),
#   array([81.17617], dtype=float32),
#   array([81.17453], dtype=float32),
#   array([81.17276], dtype=float32)],
#  30491510.0: [array([82.699585], dtype=float32),
#   array([82.697945], dtype=float32),
#   array([82.696144], dtype=float32),
#   array([82.69423], dtype=float32),
#   array([82.69224], dtype=float32),
#   array([82.69019], dtype=float32)],
#  30491512.0: [array([81.20746], dtype=float32),
#   array([81.20567], dtype=float32),
#   array([81.20407], dtype=float32),
#   array([81.202545], dtype=float32),
#   array([81.20104], dtype=float32),
#   array([81.19953], dtype=float32)],
#  30491513.0: [array([81.72599], dtype=float32),
#   array([81.72321], dtype=float32),
#   array([81.72045], dtype=float32),
#   array([81.71787], dtype=float32),
#   array([81.7155], dtype=float32),
#   array([81.71325], dtype=float32)],
#  30509090.0: [array([80.73162], dtype=float32),
#   array([82.491295], dtype=float32),
#   array([82.565926], dtype=float32),
#   array([82.58468], dtype=float32),
#   array([82.60169], dtype=float32),
#   array([82.61866], dtype=float32)],
#  30509093.0: [array([81.63715], dtype=float32),
#   array([81.63527], dtype=float32),
#   array([81.63416], dtype=float32),
#   array([81.63308], dtype=float32),
#   array([81.63202], dtype=float32),
#   array([81.63099], dtype=float32)]}

# %%
df_w.to_csv("./Seasons/winter_pred.csv")

# %% [markdown]
# ## Creating a dataframe for summer prediction

# %%
summer_count = summer_df.shape[0]

# %%
summer_count
# Out:
# 95

# %%
def summer_pred():
    sp = dict()
    for i in range (summer_count):
        row = summer_df.iloc[i]
        station_name = row["Station"]
        row = row.drop(['Station','X','Y'])
        row = np.array([row])
        predict = predict_summer(row, winter_lstm)
        
        sp[station_name] = predict
    return sp

# %%
sp = summer_pred()

# %%
sp
# Out:
# {25470023: [array([43.162106], dtype=float32),
#   array([43.160065], dtype=float32),
#   array([43.172047], dtype=float32),
#   array([43.184635], dtype=float32),
#   array([43.19688], dtype=float32)],
#  25480025: [array([69.88874], dtype=float32),
#   array([69.84257], dtype=float32),
#   array([69.83043], dtype=float32),
#   array([69.818924], dtype=float32),
#   array([69.8079], dtype=float32)],
#  25480026: [array([66.68058], dtype=float32),
#   array([66.680466], dtype=float32),
#   array([66.68281], dtype=float32),
#   array([66.68508], dtype=float32),
#   array([66.687294], dtype=float32)],
#  25481088: [array([65.831505], dtype=float32),
#   array([65.94598], dtype=float32),
#   array([65.985504], dtype=float32),
#   array([65.99791], dtype=float32),
#   array([66.00131], dtype=float32)],
#  25490020: [array([51.21232], dtype=float32),
#   array([51.649845], dtype=float32),
#   array([51.606037], dtype=float32),
#   array([51.57925], dtype=float32),
#   array([51.558228], dtype=float32)],
#  25500006: [array([38.327038], dtype=float32),
#   array([37.877228], dtype=float32),
#   array([37.575237], dtype=float32),
#   array([37.048275], dtype=float32),
#   array([36.38895], dtype=float32)],
#  25501075: [array([70.24317], dtype=float32),
#   array([69.79957], dtype=float32),
#   array([69.81855], dtype=float32),
#   array([69.81102], dtype=float32),
#   array([69.80482], dtype=float32)],
#  25510027: [array([75.5657], dtype=float32),
#   array([75.54367], dtype=float32),
#   array([75.52754], dtype=float32),
#   array([75.5127], dtype=float32),
#   array([75.49891], dtype=float32)],
#  26471092: [array([71.99448], dtype=float32),
#   array([71.87766], dtype=float32),
#   array([71.85793], dtype=float32),
#   array([71.84568], dtype=float32),
#   array([71.83489], dtype=float32)],
#  26471094: [array([76.76883], dtype=float32),
#   array([76.822174], dtype=float32),
#   array([76.818375], dtype=float32),
#   array([76.805664], dtype=float32),
#   array([76.79211], dtype=float32)],
#  26471095: [array([71.33648], dtype=float32),
#   array([71.19578], dtype=float32),
#   array([71.18427], dtype=float32),
#   array([71.17806], dtype=float32),
#   array([71.172325], dtype=float32)],
#  26471097: [array([78.28675], dtype=float32),
#   array([78.31135], dtype=float32),
#   array([78.30789], dtype=float32),
#   array([78.30221], dtype=float32),
#   array([78.29638], dtype=float32)],
#  26480022: [array([68.24496], dtype=float32),
#   array([68.24994], dtype=float32),
#   array([68.24511], dtype=float32),
#   array([68.23811], dtype=float32),
#   array([68.23048], dtype=float32)],
#  26481051: [array([72.236], dtype=float32),
#   array([72.232216], dtype=float32),
#   array([72.22721], dtype=float32),
#   array([72.22225], dtype=float32),
#   array([72.21745], dtype=float32)],
#  26481052: [array([66.58895], dtype=float32),
#   array([66.6721], dtype=float32),
#   array([66.70959], dtype=float32),
#   array([66.71397], dtype=float32),
#   array([66.71006], dtype=float32)],
#  26481057: [array([84.63501], dtype=float32),
#   array([84.60358], dtype=float32),
#   array([84.5955], dtype=float32),
#   array([84.58904], dtype=float32),
#   array([84.5826], dtype=float32)],
#  26486009: [array([73.85569], dtype=float32),
#   array([73.82943], dtype=float32),
#   array([73.82298], dtype=float32),
#   array([73.81803], dtype=float32),
#   array([73.81335], dtype=float32)],
#  26486011: [array([75.39389], dtype=float32),
#   array([75.37229], dtype=float32),
#   array([75.35987], dtype=float32),
#   array([75.34812], dtype=float32),
#   array([75.33677], dtype=float32)],
#  26486016: [array([64.17372], dtype=float32),
#   array([63.61603], dtype=float32),
#   array([63.618893], dtype=float32),
#   array([63.623325], dtype=float32),
#   array([63.627697], dtype=float32)],
#  26490030: [array([85.22359], dtype=float32),
#   array([85.20702], dtype=float32),
#   array([85.196976], dtype=float32),
#   array([85.186615], dtype=float32),
#   array([85.17645], dtype=float32)],
#  26491061: [array([70.77242], dtype=float32),
#   array([69.75603], dtype=float32),
#   array([69.41833], dtype=float32),
#   array([69.34962], dtype=float32),
#   array([69.33278], dtype=float32)],
#  26491067: [array([74.42528], dtype=float32),
#   array([74.464615], dtype=float32),
#   array([74.465485], dtype=float32),
#   array([74.46048], dtype=float32),
#   array([74.45467], dtype=float32)],
#  26500002: [array([78.56718], dtype=float32),
#   array([78.548744], dtype=float32),
#   array([78.5438], dtype=float32),
#   array([78.54046], dtype=float32),
#   array([78.537346], dtype=float32)],
#  26521010: [array([80.832245], dtype=float32),
#   array([80.78281], dtype=float32),
#   array([80.78323], dtype=float32),
#   array([80.78463], dtype=float32),
#   array([80.78604], dtype=float32)],
#  27460295: [array([35.52919], dtype=float32),
#   array([32.353508], dtype=float32),
#   array([31.11134], dtype=float32),
#   array([31.208399], dtype=float32),
#   array([29.989758], dtype=float32)],
#  27461019: [array([82.87434], dtype=float32),
#   array([83.26379], dtype=float32),
#   array([83.245384], dtype=float32),
#   array([83.227], dtype=float32),
#   array([83.208595], dtype=float32)],
#  27471020: [array([76.81092], dtype=float32),
#   array([76.90366], dtype=float32),
#   array([76.837074], dtype=float32),
#   array([76.77306], dtype=float32),
#   array([76.7129], dtype=float32)],
#  27481012: [array([56.69389], dtype=float32),
#   array([55.973774], dtype=float32),
#   array([56.071102], dtype=float32),
#   array([56.040108], dtype=float32),
#   array([56.025723], dtype=float32)],
#  27501027: [array([76.714355], dtype=float32),
#   array([73.305], dtype=float32),
#   array([72.700294], dtype=float32),
#   array([72.41621], dtype=float32),
#   array([72.31934], dtype=float32)],
#  27501047: [array([84.21381], dtype=float32),
#   array([84.16834], dtype=float32),
#   array([84.16314], dtype=float32),
#   array([84.14993], dtype=float32),
#   array([84.13523], dtype=float32)],
#  27505015: [array([85.16182], dtype=float32),
#   array([85.16006], dtype=float32),
#   array([85.15154], dtype=float32),
#   array([85.142395], dtype=float32),
#   array([85.13305], dtype=float32)],
#  27511003: [array([82.69996], dtype=float32),
#   array([82.68957], dtype=float32),
#   array([82.67927], dtype=float32),
#   array([82.66912], dtype=float32),
#   array([82.65914], dtype=float32)],
#  27511009: [array([76.07769], dtype=float32),
#   array([76.0714], dtype=float32),
#   array([76.0651], dtype=float32),
#   array([76.05886], dtype=float32),
#   array([76.05266], dtype=float32)],
#  27511010: [array([78.956795], dtype=float32),
#   array([78.9493], dtype=float32),
#   array([78.94196], dtype=float32),
#   array([78.934746], dtype=float32),
#   array([78.92765], dtype=float32)],
#  27511011: [array([64.81454], dtype=float32),
#   array([64.84982], dtype=float32),
#   array([64.8508], dtype=float32),
#   array([64.85038], dtype=float32),
#   array([64.8497], dtype=float32)],
#  27511090: [array([54.60675], dtype=float32),
#   array([54.446964], dtype=float32),
#   array([54.439037], dtype=float32),
#   array([54.442417], dtype=float32),
#   array([54.445385], dtype=float32)],
#  27519029: [array([71.26173], dtype=float32),
#   array([71.28723], dtype=float32),
#   array([71.28159], dtype=float32),
#   array([71.27549], dtype=float32),
#   array([71.269356], dtype=float32)],
#  27521005: [array([67.522255], dtype=float32),
#   array([67.238396], dtype=float32),
#   array([67.29961], dtype=float32),
#   array([67.33539], dtype=float32),
#   array([67.33992], dtype=float32)],
#  27521086: [array([62.818935], dtype=float32),
#   array([62.5432], dtype=float32),
#   array([65.2421], dtype=float32),
#   array([68.88453], dtype=float32),
#   array([69.32923], dtype=float32)],
#  28470002: [array([64.990555], dtype=float32),
#   array([64.800644], dtype=float32),
#   array([64.78005], dtype=float32),
#   array([64.7716], dtype=float32),
#   array([64.76389], dtype=float32)],
#  28480021: [array([68.203026], dtype=float32),
#   array([68.203445], dtype=float32),
#   array([68.20107], dtype=float32),
#   array([68.193436], dtype=float32),
#   array([68.1834], dtype=float32)],
#  28481093: [array([66.93188], dtype=float32),
#   array([66.89391], dtype=float32),
#   array([66.86616], dtype=float32),
#   array([66.84681], dtype=float32),
#   array([66.832466], dtype=float32)],
#  28491008: [array([76.04937], dtype=float32),
#   array([76.11516], dtype=float32),
#   array([76.1135], dtype=float32),
#   array([76.10523], dtype=float32),
#   array([76.0964], dtype=float32)],
#  28491016: [array([85.631775], dtype=float32),
#   array([85.66489], dtype=float32),
#   array([85.667915], dtype=float32),
#   array([85.66471], dtype=float32),
#   array([85.65961], dtype=float32)],
#  28500636: [array([80.80712], dtype=float32),
#   array([80.80507], dtype=float32),
#   array([80.80272], dtype=float32),
#   array([80.80035], dtype=float32),
#   array([80.79795], dtype=float32)],
#  28500652: [array([72.96877], dtype=float32),
#   array([72.963524], dtype=float32),
#   array([72.9583], dtype=float32),
#   array([72.95338], dtype=float32),
#   array([72.94868], dtype=float32)],
#  28501105: [array([61.335957], dtype=float32),
#   array([57.111977], dtype=float32),
#   array([57.004513], dtype=float32),
#   array([58.298428], dtype=float32),
#   array([58.774998], dtype=float32)],
#  28501107: [array([69.29778], dtype=float32),
#   array([68.9156], dtype=float32),
#   array([68.78603], dtype=float32),
#   array([68.745476], dtype=float32),
#   array([68.729065], dtype=float32)],
#  28501108: [array([81.89214], dtype=float32),
#   array([82.09095], dtype=float32),
#   array([82.21456], dtype=float32),
#   array([82.25666], dtype=float32),
#   array([82.28185], dtype=float32)],
#  28501111: [array([77.26841], dtype=float32),
#   array([77.428566], dtype=float32),
#   array([77.458046], dtype=float32),
#   array([77.462234], dtype=float32),
#   array([77.459656], dtype=float32)],
#  28510981: [array([68.003944], dtype=float32),
#   array([67.96748], dtype=float32),
#   array([67.97818], dtype=float32),
#   array([67.986275], dtype=float32),
#   array([67.98777], dtype=float32)],
#  28510982: [array([82.605705], dtype=float32),
#   array([82.60827], dtype=float32),
#   array([82.60596], dtype=float32),
#   array([82.60355], dtype=float32),
#   array([82.60108], dtype=float32)],
#  28511201: [array([69.29349], dtype=float32),
#   array([69.2873], dtype=float32),
#   array([69.28178], dtype=float32),
#   array([69.27697], dtype=float32),
#   array([69.27262], dtype=float32)],
#  28511202: [array([80.4372], dtype=float32),
#   array([80.43154], dtype=float32),
#   array([80.42661], dtype=float32),
#   array([80.42168], dtype=float32),
#   array([80.41657], dtype=float32)],
#  28511203: [array([70.312065], dtype=float32),
#   array([73.28919], dtype=float32),
#   array([79.07546], dtype=float32),
#   array([79.553566], dtype=float32),
#   array([79.69613], dtype=float32)],
#  28511204: [array([78.94085], dtype=float32),
#   array([78.94367], dtype=float32),
#   array([78.93655], dtype=float32),
#   array([78.92951], dtype=float32),
#   array([78.922676], dtype=float32)],
#  28511207: [array([75.35663], dtype=float32),
#   array([75.35098], dtype=float32),
#   array([75.34577], dtype=float32),
#   array([75.34068], dtype=float32),
#   array([75.33571], dtype=float32)],
#  28511210: [array([62.600094], dtype=float32),
#   array([60.671978], dtype=float32),
#   array([60.33585], dtype=float32),
#   array([60.207558], dtype=float32),
#   array([60.232605], dtype=float32)],
#  28511229: [array([67.52569], dtype=float32),
#   array([67.54209], dtype=float32),
#   array([67.51266], dtype=float32),
#   array([67.50788], dtype=float32),
#   array([67.502495], dtype=float32)],
#  28511230: [array([72.168015], dtype=float32),
#   array([72.21934], dtype=float32),
#   array([72.2221], dtype=float32),
#   array([72.220795], dtype=float32),
#   array([72.21895], dtype=float32)],
#  28511231: [array([68.03756], dtype=float32),
#   array([68.487625], dtype=float32),
#   array([68.50192], dtype=float32),
#   array([68.50367], dtype=float32),
#   array([68.50479], dtype=float32)],
#  28519035: [array([84.64759], dtype=float32),
#   array([84.648285], dtype=float32),
#   array([84.64765], dtype=float32),
#   array([84.6466], dtype=float32),
#   array([84.64527], dtype=float32)],
#  29470010: [array([83.627426], dtype=float32),
#   array([83.62363], dtype=float32),
#   array([83.620155], dtype=float32),
#   array([83.61693], dtype=float32),
#   array([83.61385], dtype=float32)],
#  29472968: [array([80.152214], dtype=float32),
#   array([80.14829], dtype=float32),
#   array([80.144424], dtype=float32),
#   array([80.14045], dtype=float32),
#   array([80.136314], dtype=float32)],
#  29472981: [array([65.2795], dtype=float32),
#   array([69.780014], dtype=float32),
#   array([69.867455], dtype=float32),
#   array([69.88323], dtype=float32),
#   array([69.89745], dtype=float32)],
#  29481334: [array([82.59712], dtype=float32),
#   array([82.50465], dtype=float32),
#   array([82.49945], dtype=float32),
#   array([82.49792], dtype=float32),
#   array([82.49677], dtype=float32)],
#  29483281: [array([69.0619], dtype=float32),
#   array([69.466896], dtype=float32),
#   array([69.50405], dtype=float32),
#   array([69.510445], dtype=float32),
#   array([69.51017], dtype=float32)],
#  29484282: [array([78.39901], dtype=float32),
#   array([78.28272], dtype=float32),
#   array([78.25936], dtype=float32),
#   array([78.24511], dtype=float32),
#   array([78.23267], dtype=float32)],
#  29490617: [array([62.002487], dtype=float32),
#   array([59.814476], dtype=float32),
#   array([59.02625], dtype=float32),
#   array([58.773685], dtype=float32),
#   array([58.680668], dtype=float32)],
#  29490626: [array([82.20852], dtype=float32),
#   array([82.21558], dtype=float32),
#   array([82.21261], dtype=float32),
#   array([82.20951], dtype=float32),
#   array([82.20635], dtype=float32)],
#  29490630: [array([83.80862], dtype=float32),
#   array([83.80735], dtype=float32),
#   array([83.80596], dtype=float32),
#   array([83.80449], dtype=float32),
#   array([83.80292], dtype=float32)],
#  29490632: [array([82.01345], dtype=float32),
#   array([82.01122], dtype=float32),
#   array([82.00895], dtype=float32),
#   array([82.00663], dtype=float32),
#   array([82.00428], dtype=float32)],
#  29490634: [array([79.68983], dtype=float32),
#   array([79.68257], dtype=float32),
#   array([79.54594], dtype=float32),
#   array([79.58556], dtype=float32),
#   array([79.59823], dtype=float32)],
#  29491338: [array([81.682175], dtype=float32),
#   array([82.27746], dtype=float32),
#   array([82.30865], dtype=float32),
#   array([82.31521], dtype=float32),
#   array([82.31788], dtype=float32)],
#  29499501: [array([75.60167], dtype=float32),
#   array([76.085266], dtype=float32),
#   array([76.1438], dtype=float32),
#   array([76.152115], dtype=float32),
#   array([76.15162], dtype=float32)],
#  29499502: [array([75.999146], dtype=float32),
#   array([76.008934], dtype=float32),
#   array([76.00591], dtype=float32),
#   array([76.00289], dtype=float32),
#   array([75.99994], dtype=float32)],
#  29499503: [array([64.2641], dtype=float32),
#   array([63.77261], dtype=float32),
#   array([63.7839], dtype=float32),
#   array([63.734623], dtype=float32),
#   array([63.62764], dtype=float32)],
#  29501404: [array([74.47765], dtype=float32),
#   array([74.69894], dtype=float32),
#   array([74.719734], dtype=float32),
#   array([74.71922], dtype=float32),
#   array([74.71624], dtype=float32)],
#  29510149: [array([65.18969], dtype=float32),
#   array([65.18235], dtype=float32),
#   array([65.183], dtype=float32),
#   array([65.18316], dtype=float32),
#   array([65.18299], dtype=float32)],
#  29510657: [array([62.00854], dtype=float32),
#   array([63.106438], dtype=float32),
#   array([65.27754], dtype=float32),
#   array([65.269775], dtype=float32),
#   array([65.24751], dtype=float32)],
#  29510999: [array([80.43897], dtype=float32),
#   array([80.44375], dtype=float32),
#   array([80.44085], dtype=float32),
#   array([80.43775], dtype=float32),
#   array([80.43467], dtype=float32)],
#  29519002: [array([54.3041], dtype=float32),
#   array([53.60854], dtype=float32),
#   array([54.252346], dtype=float32),
#   array([54.31779], dtype=float32),
#   array([54.344246], dtype=float32)],
#  29519017: [array([78.77203], dtype=float32),
#   array([78.81489], dtype=float32),
#   array([78.81109], dtype=float32),
#   array([78.805534], dtype=float32),
#   array([78.799774], dtype=float32)],
#  29519021: [array([70.504074], dtype=float32),
#   array([70.49222], dtype=float32),
#   array([70.47772], dtype=float32),
#   array([70.46496], dtype=float32),
#   array([70.45536], dtype=float32)],
#  29519023: [array([70.51124], dtype=float32),
#   array([70.45999], dtype=float32),
#   array([70.426445], dtype=float32),
#   array([70.39742], dtype=float32),
#   array([70.37049], dtype=float32)],
#  29519026: [array([79.44145], dtype=float32),
#   array([79.459915], dtype=float32),
#   array([79.45531], dtype=float32),
#   array([79.449936], dtype=float32),
#   array([79.44461], dtype=float32)],
#  29519042: [array([71.43129], dtype=float32),
#   array([70.73625], dtype=float32),
#   array([70.44387], dtype=float32),
#   array([70.376305], dtype=float32),
#   array([70.35795], dtype=float32)],
#  30491504: [array([75.046295], dtype=float32),
#   array([75.41124], dtype=float32),
#   array([75.60588], dtype=float32),
#   array([75.65003], dtype=float32),
#   array([75.660095], dtype=float32)],
#  30491505: [array([75.044685], dtype=float32),
#   array([75.16315], dtype=float32),
#   array([75.190575], dtype=float32),
#   array([75.19999], dtype=float32),
#   array([75.20342], dtype=float32)],
#  30491509: [array([80.34856], dtype=float32),
#   array([80.346825], dtype=float32),
#   array([80.34465], dtype=float32),
#   array([80.34261], dtype=float32),
#   array([80.34066], dtype=float32)],
#  30491510: [array([70.835304], dtype=float32),
#   array([70.8343], dtype=float32),
#   array([70.83282], dtype=float32),
#   array([70.83111], dtype=float32),
#   array([70.829216], dtype=float32)],
#  30491512: [array([86.07508], dtype=float32),
#   array([86.07218], dtype=float32),
#   array([86.07026], dtype=float32),
#   array([86.06877], dtype=float32),
#   array([86.06747], dtype=float32)],
#  30491513: [array([64.24418], dtype=float32),
#   array([64.161896], dtype=float32),
#   array([64.06018], dtype=float32),
#   array([64.01126], dtype=float32),
#   array([63.99367], dtype=float32)],
#  30509090: [array([60.95171], dtype=float32),
#   array([62.625175], dtype=float32),
#   array([62.827374], dtype=float32),
#   array([62.85355], dtype=float32),
#   array([62.86307], dtype=float32)],
#  30509093: [array([81.711945], dtype=float32),
#   array([81.45259], dtype=float32),
#   array([81.40608], dtype=float32),
#   array([81.390755], dtype=float32),
#   array([81.381645], dtype=float32)]}
